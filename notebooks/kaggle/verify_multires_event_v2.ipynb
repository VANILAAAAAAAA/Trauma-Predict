# %% [markdown]
# # Historical V8 verification Notebook — disabled
#
# This verification surface belongs to the retired V8 mode contract. It cannot verify or authorize Relation Contract V2.

# %%
raise RuntimeError(
    'HISTORICAL_MULTIRES_EVENT_V2_VERIFICATION_DISABLED: Relation V2 hosted verification is pending.'
)
